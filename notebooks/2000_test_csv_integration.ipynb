# %%
import os
# change working directory to ../src
os.chdir('../src')
print(f"Working directory: {os.getcwd()}")

from utils.local import *
# Out:
# Working directory: /home/pop540331/git/seek2judge-annotations/src

# %% [markdown]
# # loadTasks

# %%
loadTasks()
# Out:
# [{'_id': '64afe343252b9e022e8c67d8',
#   'target_url': 'http://de.mail.yahoo.com/d/folders/1/messages/45364?guce_referrer=aHR0cHM6Ly93d3cuYmluZy5jb20vc2VhcmNoP3E9bWVpbit5YWhvbyErbWFpbCtwb3N0ZWluZ2FuZyZGT1JNPVFTUkUx&guce_referrer_sig=AQAAAGSDXvQKjQKSPoCcdjrZ_3wGL6vshTeHRji_vedXmT9Gw6eaWAPIYDNo7Mgfh2GyV_JEBROex1lZvpGWbK9lXFOaifAn1ny4pDU8jndhc_diERVOGexnI5g6NnkrcYqGQA3Iomg1hBkvFjyqyjz0JVLwx85h39NV1HzV1sqdKazN',
#   'count': 2,
#   'status': 'PROCESSED-STATIC',
#   'content_requests': '64b5667e201ec49edb9958fc',
#   'scraped_at': '2023-07-17 16:03:54.800',
# ...

# %%
getPageContent("1")
# Out:
# 'This is the content of the page'

# %%
loadAnnotations()
# Out:
# [{'_id': '64afe343252b9e022e8cdfc1',
#   'annotations': "{'Anton Pogrebnjak': {'comment': '', 'labels': []}}"},
#  {'_id': '64afe342252b9e022e8b22f9',
#   'annotations': "{'Anton Pogrebnjak': {'comment': '', 'labels': []}}"}]

# %%
updateTask("64afe343252b9e022e8cdfc1", "Anton Pogrebnjak", {
    'comment': 'I have added a new annotation',
    'labels': [],
})

loadAnnotations()
# Out:
# [{'_id': '64afe343252b9e022e8cdfc1',
#   'annotations': "{'Anton Pogrebnjak': {'comment': 'I have added a new annotation', 'labels': []}}"},
#  {'_id': '64afe342252b9e022e8b22f9',
#   'annotations': "{'Anton Pogrebnjak': {'comment': '', 'labels': []}}"}]
